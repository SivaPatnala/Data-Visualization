# %% [markdown]
# **This notebook is an exercise in the [Data Visualization](https://www.kaggle.com/learn/data-visualization) course.  You can reference the tutorial at [this link](https://www.kaggle.com/alexisbcook/distributions).**
#
# ---

# %% [markdown]
# In this exercise, you will use your new knowledge to propose a solution to a real-world scenario.  To succeed, you will need to import data into Python, answer questions using the data, and generate **histograms** and **density plots** to understand patterns in the data.
#
# ## Scenario
#
# You'll work with a real-world dataset containing information collected from microscopic images of breast cancer tumors, similar to the image below.
#
# ![ex4_cancer_image](https://storage.googleapis.com/kaggle-media/learn/images/qUESsJe.png)
#
# Each tumor has been labeled as either [**benign**](https://en.wikipedia.org/wiki/Benign_tumor) (_noncancerous_) or **malignant** (_cancerous_).
#
# To learn more about how this kind of data is used to create intelligent algorithms to classify tumors in medical settings, **watch the short video [at this link](https://www.youtube.com/watch?v=9Mz84cwVmS0)**.

# %% [markdown]
# ## Setup
#
# Run the next cell to import and configure the Python libraries that you need to complete the exercise.

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# The questions below will give you feedback on your work. Run the following cell to set up our feedback system.

# %%
# Set up code checking
from learntools.core import binder
binder.bind(globals())
from learntools.data_viz_to_coder.ex5 import *
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# ## Step 1: Load the data
#
# In this step, you will load the data.
# - Load the data file into a DataFrame called `cancer_data`.
# - The corresponding filepath is `cancer_filepath`.
# - Use the `"Id"` column to label the rows.

# %%
# Path of the files to read
cancer_filepath = "../input/cancer.csv"

# Fill in the line below to read the file into a variable cancer_data
cancer_data = pd.read_csv(cancer_filepath, index_col="Id")

# Run the line below with no changes to check that you've loaded the data correctly
step_1.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#step_1.hint()
#step_1.solution()

# %% [markdown]
# ## Step 2: Review the data
#
# Use a Python command to print the first 5 rows of the data.

# %%
# Print the first five rows of the data
cancer_data.head(5) # Your code here
# Out:
#          Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Id
# 8510426          B         13.540           14.36             87.46
# 8510653          B         13.080           15.71             85.63
# 8510824          B          9.504           12.44             60.34
# 854941           B         13.030           18.42             82.61
# 85713702         B          8.196           16.84             51.71
#
#           Area (mean)  Smoothness (mean)  Compactness (mean)  \
# Id
# 8510426         566.3            0.09779             0.08129
# 8510653         520.0            0.10750             0.12700
# 8510824         273.9            0.10240             0.06492
# 854941          523.8            0.08983             0.03766
# 85713702        201.9            0.08600             0.05943
#
#           Concavity (mean)  Concave points (mean)  Symmetry (mean)  ...  \
# Id                                                                  ...
# ...

# %% [markdown]
# In the dataset, each row corresponds to a different image.  The dataset has 31 different columns, corresponding to:
# - 1 column (`'Diagnosis'`) that classifies tumors as either benign (which appears in the dataset as **`B`**) or malignant (__`M`__), and
# - 30 columns containing different measurements collected from the images.
#
# Use the first 5 rows of the data to answer the questions below.

# %%
# Fill in the line below: In the first five rows of the data, what is the
# largest value for 'Perimeter (mean)'?
max_perim = 87.46

# Fill in the line below: What is the value for 'Radius (mean)' for the tumor with Id 8510824?
mean_radius = 9.504

# Check your answers
step_2.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#step_2.hint()
#step_2.solution()

# %% [markdown]
# ## Step 3: Investigating differences

# %% [markdown]
# #### Part A
#
# Use the code cell below to create two histograms that show the distribution in values for `'Area (mean)'`, separately for both benign and malignant tumors.  (_To permit easy comparison, create a single figure containing both histograms in the code cell below._)

# %%
# Histograms for benign and maligant tumors
sns.histplot(data=cancer_data, x='Area (mean)', hue='Diagnosis')

# Check your answer
step_3.a.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#step_3.a.hint()
#step_3.a.solution_plot()

# %% [markdown]
# #### Part B
#
# A researcher approaches you for help with identifying how the `'Area (mean)'` column can be used to understand the difference between benign and malignant tumors.  Based on the histograms above,
# - Do malignant tumors have higher or lower values for `'Area (mean)'` (relative to benign tumors), on average?
# - Which tumor type seems to have a larger range of potential values?

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=cancer_data, x='Area (mean)', hue='Diagnosis', kde=True)
plt.title('Distribution of Area (mean) for Benign and Malignant Tumors')
plt.show()

# Calculate mean and range for 'Area (mean)' for benign and malignant tumors
mean_area_benign = cancer_data[cancer_data['Diagnosis'] == 'B']['Area (mean)'].mean()
mean_area_malignant = cancer_data[cancer_data['Diagnosis'] == 'M']['Area (mean)'].mean()

range_area_benign = cancer_data[cancer_data['Diagnosis'] == 'B']['Area (mean)'].max() - cancer_data[cancer_data['Diagnosis'] == 'B']['Area (mean)'].min()
range_area_malignant = cancer_data[cancer_data['Diagnosis'] == 'M']['Area (mean)'].max() - cancer_data[cancer_data['Diagnosis'] == 'M']['Area (mean)'].min()
answer_1 = "Malignant tumors have higher values for 'Area (mean)' on average."
answer_2 = "Malignant tumors seem to have a larger range of potential values for 'Area (mean).'"

# %%
#step_3.b.hint()

# %%
# Check your answer (Run this code cell to receive credit!)
step_3.b.solution()
# Out:
# Solution: Malignant tumors have higher values for `'Area (mean)'`, on average. Malignant tumors have a larger range of potential values.

# %% [markdown]
# ## Step 4: A very useful column
#
# #### Part A
#
# Use the code cell below to create two KDE plots that show the distribution in values for `'Radius (worst)'`, separately for both benign and malignant tumors.  (_To permit easy comparison, create a single figure containing both KDE plots in the code cell below._)

# %%
# KDE plots for benign and malignant tumors
sns.kdeplot(data=cancer_data, x='Radius (worst)', hue='Diagnosis', shade=True)

# Check your answer
step_4.a.check()
# Out:
# /tmp/ipykernel_42/4128063534.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=cancer_data, x='Radius (worst)', hue='Diagnosis', shade=True)
# Correct

# %%
# Lines below will give you a hint or solution code
#step_4.a.hint()
#step_4.a.solution_plot()

# %% [markdown]
# #### Part B
#
# A hospital has recently started using an algorithm that can diagnose tumors with high accuracy.  Given a tumor with a value for `'Radius (worst)'` of 25, do you think the algorithm is more likely to classify the tumor as benign or malignant?

# %%
sns.kdeplot(data=cancer_data, x='Radius (worst)', hue='Diagnosis', fill=True)

# Add a vertical line at 'Radius (worst)' = 25
plt.axvline(x=25, color='red', linestyle='--', label="Tumor with Radius 25")

# Display legend
plt.legend()

# Set plot labels and title
plt.xlabel('Radius (worst)')
plt.ylabel('Density')
plt.title('KDE Plot for Radius (worst) - Benign vs Malignant Tumors')

# Show the plot
plt.show()

# %%
#step_4.b.hint()

# %%
# Check your answer (Run this code cell to receive credit!)
step_4.b.solution()
# Out:
# Solution: The algorithm is more likely to classify the tumor as malignant. This is because the curve for malignant tumors is much higher than the curve for benign tumors around a value of 25 -- and an algorithm that gets high accuracy is likely to make decisions based on this pattern in the data.

# %% [markdown]
# ## Keep going
#
# Review all that you've learned and explore how to further customize your plots in the **[next tutorial](https://www.kaggle.com/alexisbcook/choosing-plot-types-and-custom-styles)**!

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/data-visualization/discussion) to chat with other learners.*
